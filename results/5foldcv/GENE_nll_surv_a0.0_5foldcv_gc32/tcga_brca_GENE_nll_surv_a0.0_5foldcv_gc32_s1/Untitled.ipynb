# %%
import pickle

f = pickle.load(open('split_latest_val_0_results.pkl', 'rb'))
print(f)
# Out:
# {'TCGA-5T-A9QA': {'slide_id': array('TCGA-5T-A9QA', dtype='<U12'), 'risk': -3.657153606414795, 'disc_label': 0, 'survival': 9.95, 'censorship': 1.0}, 'TCGA-A1-A0SB': {'slide_id': array('TCGA-A1-A0SB', dtype='<U12'), 'risk': -3.4028172492980957, 'disc_label': 0, 'survival': 8.51, 'censorship': 1.0}, 'TCGA-A1-A0SE': {'slide_id': array('TCGA-A1-A0SE', dtype='<U12'), 'risk': -1.1289957761764526, 'disc_label': 1, 'survival': 43.4, 'censorship': 1.0}, 'TCGA-A1-A0SI': {'slide_id': array('TCGA-A1-A0SI', dtype='<U12'), 'risk': -3.4584755897521973, 'disc_label': 0, 'survival': 20.86, 'censorship': 1.0}, 'TCGA-A1-A0SJ': {'slide_id': array('TCGA-A1-A0SJ', dtype='<U12'), 'risk': -3.261643648147583, 'disc_label': 0, 'survival': 13.67, 'censorship': 1.0}, 'TCGA-A2-A04R': {'slide_id': array('TCGA-A2-A04R', dtype='<U12'), 'risk': -3.4223108291625977, 'disc_label': 3, 'survival': 121.85, 'censorship': 1.0}, 'TCGA-A2-A04V': {'slide_id': array('TCGA-A2-A04V', dtype='<U12'), 'risk': -3.306400775909424, '
# ...
